# %%
import pandas as pd

# %%
df = pd.read_csv('/home/yusuf/Masaüstü/Machine-learning/data/bank-additional-full.csv',sep=';')

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df.drop(["month","day_of_week"],axis=1,inplace=True)

# %%
df.shape
# Out:
# (41188, 19)

# %%
df.education.value_counts()
# Out:
# education
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder(categories=[[
    'illiterate', 'unknown', 'basic.4y', 'basic.6y', 'basic.9y',
    'high.school', 'professional.course', 'university.degree'
]])

df['education_encoded'] = encoder.fit_transform(df[['education']])

# %%
df.education_encoded.value_counts()
# Out:
# education_encoded
# 7.0    12168
# 5.0     9515
# 4.0     6045
# 6.0     5243
# 2.0     4176
# 3.0     2292
# 1.0     1731
# 0.0       18
# Name: count, dtype: int64

# %%
df.drop(['education'],axis=1,inplace=True)

# %%
df = df[df['job'] != 'unknown']

# %%
import matplotlib.pyplot as plt

df['job'].value_counts().plot(kind='bar', figsize=(12,6))
plt.title('Meslek Dağılımı')
plt.xlabel('Meslek')
plt.ylabel('Kişi Sayısı')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

job_y_counts = df.groupby(['job', 'y']).size().unstack(fill_value=0)

job_y_counts.plot(kind='bar', figsize=(12, 6))
plt.title('Vadeli Hesap Açma Durumu')
plt.xlabel('Meslek')
plt.ylabel('Kişi Sayısı')
plt.xticks(rotation=45)
plt.legend(title='Açtı mı?')
plt.tight_layout()
plt.show()

# %%
df = df[df['marital']!='unknown']

# %%
df.marital.value_counts()
# Out:
# marital
# married     24694
# single      11494
# divorced     4599
# Name: count, dtype: int64

# %%
df['marital'].value_counts().plot(kind='bar', figsize=(8,5))
# Out:
# <Axes: xlabel='marital'>

# %%
df = pd.get_dummies(df, columns=['marital'], prefix='marital')

# %%
df.columns
# Out:
# Index(['age', 'job', 'default', 'housing', 'loan', 'contact', 'duration',
#        'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'y',
#        'education_encoded', 'marital_divorced', 'marital_married',
#        'marital_single'],
#       dtype='object')

# %%
df = df[df['housing']!='unknown']

# %%
df.housing.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='housing'>

# %%
df['housing_encoded'] = df['housing'].apply(lambda x: 1 if x=='yes' else 0)

# %%
df.housing_encoded.value_counts()
# Out:
# housing_encoded
# 1    21376
# 0    18427
# Name: count, dtype: int64

# %%
df.drop(['housing'],axis=1,inplace=True)

# %%
df.loan.value_counts()
# Out:
# loan
# no     33620
# yes     6183
# Name: count, dtype: int64

# %%
df['loan_encoded'] = df['loan'].apply(lambda x: 1 if x=='yes' else 0)

df.drop(['loan'],axis=1,inplace=True)

# %%
df.default.value_counts()

df.drop(['default'],axis=1,inplace=True)

# %%
df.campaign.value_counts()
# Out:
# campaign
# 1     17040
# 2     10225
# 3      5159
# 4      2563
# 5      1558
# 6       947
# 7       607
# 8       385
# 9       268
# 10      214
# 11      175
# 12      119
# 13       86
# 14       66
# 17       56
# 16       48
# 15       47
# 18       31
# 20       30
# 19       25
# 21       22
# 22       17
# 23       16
# 24       15
# 27       11
# 29       10
# 28        8
# 25        8
# 26        8
# 30        7
# 31        7
# 35        5
# 33        4
# 32        4
# 34        3
# 40        2
# 42        2
# 43        2
# 39        1
# 37        1
# 41        1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df['campaign'].hist(bins=30, figsize=(8,5))
plt.title('Campaign Değeri Dağılımı')
plt.xlabel('Arama Sayısı')
plt.ylabel('Kişi Sayısı')
plt.show()

# %%
import numpy as np
df['campaign_log'] = np.log1p(df['campaign'])  # log(1 + x)
df['campaign_log'].hist(bins=30, figsize=(8,5))
df.drop('campaign',axis=1,inplace=True)
plt.title('Log Dönüşümlü Campaign Dağılımı')
plt.xlabel('log(1 + Arama Sayısı)')
plt.ylabel('Kişi Sayısı')
plt.show()

# %%
df.age.value_counts()
# Out:
# age
# 31    1895
# 32    1779
# 33    1765
# 36    1734
# 35    1701
#       ...
# 91       2
# 89       2
# 95       1
# 94       1
# 87       1
# Name: count, Length: 78, dtype: int64

# %%
df['age'].hist(bins=30, figsize=(8,5))
# Out:
# <Axes: >

# %%
df.pdays.value_counts()
# Out:
# pdays
# 999    38347
# 3        421
# 6        396
# 4        113
# 9         62
# 7         58
# 2         58
# 12        56
# 10        48
# 5         46
# 13        35
# 11        27
# 1         25
# 15        24
# 14        20
# 0         15
# 8         15
# 16        10
# 17         8
# 18         7
# 22         3
# 19         3
# 21         2
# 25         1
# 26         1
# 27         1
# 20         1
# Name: count, dtype: int64

# %%
df['was_contacted_before'] = df['pdays'].apply(lambda x: 0 if x == 999 else 1) # kategorik değere alınarak daha sistematik bir hale geitirikldi
df.drop('pdays',axis=1,inplace=True)

# %%
df.poutcome.value_counts()
# Out:
# poutcome
# nonexistent    34372
# failure         4110
# success         1321
# Name: count, dtype: int64

# %%
poutcome_map = {
    'failure': -1,
    'nonexistent': 0,
    'success': 1
}
df['poutcome_encoded'] = df['poutcome'].map(poutcome_map)
df.drop('poutcome',axis=1,inplace=True)

# %%
df.previous.value_counts()
# Out:
# previous
# 0    34372
# 1     4412
# 2      722
# 3      207
# 4       66
# 5       18
# 6        5
# 7        1
# Name: count, dtype: int64

# %%
df['categorized_prev'] = df['previous'].apply(lambda x: 0 if x==0 else 1) 
df.drop('previous',axis=1, inplace=True)

# %%
df.categorized_prev.value_counts()
# Out:
# categorized_prev
# 0    34372
# 1     5431
# Name: count, dtype: int64

# %%
df.shape
print(df.columns)
# Out:
# Index(['age', 'job', 'contact', 'duration', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'education_encoded',
#        'marital_divorced', 'marital_married', 'marital_single',
#        'housing_encoded', 'loan_encoded', 'campaign_log',
#        'was_contacted_before', 'poutcome_encoded', 'categorized_prev'],
#       dtype='object')

# %%
df.duration.value_counts()
# Out:
# duration
# 85      167
# 90      166
# 87      159
# 136     159
# 124     158
#        ...
# 1326      1
# 1380      1
# 1804      1
# 1628      1
# 2184      1
# Name: count, Length: 1532, dtype: int64

# %%
Q1 = df['duration']
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 df['duration'].plot(kind='bar')
#
# File ~/.pyenv/versions/3.12.2/envs/myenv/lib/python3.12/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/.pyenv/versions/3.12.2/envs/myenv/lib/python3.12/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/.pyenv/versions/3.12.2/envs/myenv/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:508, in MPLPlot.generate(self)
#     506 for ax in self.axes:
#     507     self._post_plot_logic_common(ax)
# --> 508     self._post_plot_logic(ax, self.data)
#
# File ~/.pyenv/versions/3.12.2/envs/myenv/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:1975, in BarPlot._post_plot_logic(self, ax, data)
#    1972 s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    1973 e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
# -> 1975 self._decorate_ticks(ax, self._get_index_name(), str_index, s_edge, e_edge)
#
# File ~/.pyenv/versions/3.12.2/envs/myenv/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:1990, in BarPlot._decorate_ticks(self, ax, name, ticklabels, start_edge, end_edge)
#    1988     ax.set_xticks(np.array(self.xticks))
#    1989 else:
# -> 1990     ax.set_xticks(self.tick_pos)
#    1991     ax.set_xticklabels(ticklabels)
#    1993 if name is not None and self.use_index:
#
# File ~/.pyenv/versions/3.12.2/envs/myenv/lib/python3.12/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.2/envs/myenv/lib/python3.12/site-packages/matplotlib/axis.py:2218, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    2213     first_key = next(iter(kwargs))
#    2214     raise ValueError(
#    2215         f"Incorrect use of keyword argument {first_key!r}. Keyword arguments "
#    2216         "other than 'minor' modify the text labels and can only be used if "
#    2217         "'labels' are passed as well.")
# -> 2218 result = self._set_tick_locations(ticks, minor=minor)
#    2219 if labels is not None:
#    2220     self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File ~/.pyenv/versions/3.12.2/envs/myenv/lib/python3.12/site-packages/matplotlib/axis.py:2170, in Axis._set_tick_locations(self, ticks, minor)
#    2168 else:
#    2169     self.set_major_locator(locator)
# -> 2170     return self.get_major_ticks(len(ticks))
#
# File ~/.pyenv/versions/3.12.2/envs/myenv/lib/python3.12/site-packages/matplotlib/axis.py:1664, in Axis.get_major_ticks(self, numticks)
#    1660     numticks = len(self.get_majorticklocs())
#    1662 while len(self.majorTicks) < numticks:
#    1663     # Update the new tick label properties from the old.
# -> 1664     tick = self._get_tick(major=True)
#    1665     self.majorTicks.append(tick)
#    1666     self._copy_tick_props(self.majorTicks[0], tick)
#
# File ~/.pyenv/versions/3.12.2/envs/myenv/lib/python3.12/site-packages/matplotlib/axis.py:1592, in Axis._get_tick(self, major)
#    1588     raise NotImplementedError(
#    1589         f"The Axis subclass {self.__class__.__name__} must define "
#    1590         "_tick_class or reimplement _get_tick()")
#    1591 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1592 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File ~/.pyenv/versions/3.12.2/envs/myenv/lib/python3.12/site-packages/matplotlib/axis.py:368, in XTick.__init__(self, *args, **kwargs)
#     367 def __init__(self, *args, **kwargs):
# --> 368     super().__init__(*args, **kwargs)
#     369     # x in data coords, y in axes coords
#     370     ax = self.axes
#
# File ~/.pyenv/versions/3.12.2/envs/myenv/lib/python3.12/site-packages/matplotlib/axis.py:176, in Tick.__init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, labelfontfamily, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kwargs)
#     170 self.gridline.get_path()._interpolation_steps = \
#     171     GRIDLINE_INTERPOLATION_STEPS
#     172 self.label1 = mtext.Text(
#     173     np.nan, np.nan,
#     174     fontsize=labelsize, color=labelcolor, visible=label1On,
#     175     fontfamily=labelfontfamily, rotation=self._labelrotation[1])
# --> 176 self.label2 = mtext.Text(
#     177     np.nan, np.nan,
#     178     fontsize=labelsize, color=labelcolor, visible=label2On,
#     179     fontfamily=labelfontfamily, rotation=self._labelrotation[1])
#     181 self._apply_tickdir(tickdir)
#     183 for artist in [self.tick1line, self.tick2line, self.gridline,
#     184                self.label1, self.label2]:
#
# File ~/.pyenv/versions/3.12.2/envs/myenv/lib/python3.12/site-packages/matplotlib/text.py:155, in Text.__init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, transform_rotates_text, parse_math, antialiased, **kwargs)
#     138 self._text = ''
#     139 self._reset_visual_defaults(
#     140     text=text,
#     141     color=color,
#    (...)    153     antialiased=antialiased
#     154 )
# --> 155 self.update(kwargs)
#
# File ~/.pyenv/versions/3.12.2/envs/myenv/lib/python3.12/site-packages/matplotlib/text.py:205, in Text.update(self, kwargs)
#     203 # Update bbox last, as it depends on font properties.
#     204 bbox = kwargs.pop("bbox", sentinel)
# --> 205 ret.extend(super().update(kwargs))
#     206 if bbox is not sentinel:
#     207     ret.append(self.set_bbox(bbox))
#
# File ~/.pyenv/versions/3.12.2/envs/myenv/lib/python3.12/site-packages/matplotlib/artist.py:1223, in Artist.update(self, props)
#    1215 def update(self, props):
#    1216     """
#    1217     Update this artist's properties from the dict *props*.
#    1218
#    (...)   1221     props : dict
#    1222     """
# -> 1223     return self._update_props(
#    1224         props, "{cls.__name__!r} object has no property {prop_name!r}")
#
# File ~/.pyenv/versions/3.12.2/envs/myenv/lib/python3.12/site-packages/matplotlib/artist.py:1209, in Artist._update_props(self, props, errfmt)
#    1205             if not callable(func):
#    1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
# -> 1209             ret.append(func(v))
#    1210 if ret:
#    1211     self.pchanged()
#
# File ~/.pyenv/versions/3.12.2/envs/myenv/lib/python3.12/site-packages/matplotlib/artist.py:1065, in Artist.set_visible(self, b)
#    1063 if b != self._visible:
#    1064     self._visible = b
# -> 1065     self.pchanged()
#    1066     self.stale = True
#
# File ~/.pyenv/versions/3.12.2/envs/myenv/lib/python3.12/site-packages/matplotlib/artist.py:414, in Artist.pchanged(self)
#     405     """
#     406     Remove a callback based on its observer id.
#     407
#    (...)    410     add_callback
#     411     """
#     412     self._callbacks.disconnect(oid)
# --> 414 def pchanged(self):
#     415     """
#     416     Call all of the registered callbacks.
#     417
#    (...)    423     remove_callback
#     424     """
#     425     self._callbacks.process("pchanged")
#
# KeyboardInterrupt:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x748469236030>>
# Traceback (most recent call last):
#   File "/home/yusuf/.pyenv/versions/3.12.2/envs/myenv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df['age'])
plt.title('Yaş Değeri - Boxplot')
plt.show()

# %% [markdown]
# uç değerler için kısıtlama yapacağım

# %%
Q1 = df['age'].quantile(0.25)
